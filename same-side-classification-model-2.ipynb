# %% [markdown]
# # RATIO 2019 - Benchmarking Workshop

# %%
# %load_ext autoreload
import os
os.environ['CUDA_VISIBLE_DEVICES']='6'
os.environ['CUDA_LAUNCH_BLOCKING']='1'

from torch.utils.data import DataLoader,Dataset
from torch.autograd import Variable
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import time
import copy
from torch.optim import lr_scheduler
import os
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import pandas as pd

# %%
import pandas as pd
import csv
import numpy as np
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
from sklearn.model_selection import train_test_split
import nltk
nltk.download('wordnet')
def get_train_test_sets(df):
    X = df[['argument1', 'argument2', 'topic']]
    y = df[['is_same_side']]

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=1, shuffle=True)
    return X_train, X_test, y_train, y_test
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Task 1 - Same Side Clasiification

# %%
data_cross_path = 'data/same-side-classification/cross-topic/{}.csv'
data_within_path = 'data/same-side-classification/within-topic/{}.csv'

# %% [markdown]
# ### Load within-topics and cross-topics data

# %%
cross_traindev_df = pd.read_csv(data_cross_path.format('training'), 
                                quotechar='"',quoting=csv.QUOTE_ALL,encoding='utf-8',escapechar='\\',doublequote=False, dtype={'topic': 'str'}, index_col='id')
cross_test_df =  pd.read_csv(data_cross_path.format('test'), 
                                quotechar='"',quoting=csv.QUOTE_ALL,encoding='utf-8',escapechar='\\',doublequote=False, dtype={'topic': 'str'}, index_col='id')

within_traindev_df =  pd.read_csv(data_within_path.format('training'), 
                                quotechar='"',quoting=csv.QUOTE_ALL,encoding='utf-8',escapechar='\\',doublequote=False, dtype={'topic': 'str'}, index_col='id')
within_test_df =  pd.read_csv(data_within_path.format('test'), 
                                quotechar='"',quoting=csv.QUOTE_ALL,encoding='utf-8',escapechar='\\',doublequote=False, dtype={'topic': 'str'}, index_col='id')

# %%
# Adding a tag for the topics in focus: "gay marriage" and "abortion"
def add_tag(row):
    title = row['topic'].lower().strip()
    if title.find('abortion') > -1 :
        row['tag'] = 'abortion'
    elif title.find('gay marriage') > -1 :
        row['tag'] = 'gay marriage'
    else:
        row['tag'] = 'NA'
    return row

cross_traindev_df = cross_traindev_df.apply(add_tag, axis=1)
cross_test_df = cross_test_df.apply(add_tag, axis=1)

within_traindev_df = within_traindev_df.apply(add_tag, axis=1)
within_test_df = within_test_df.apply(add_tag, axis=1)

# %%
within_traindev_df['tag'].unique()
# Out:
# array(['gay marriage', 'abortion'], dtype=object)

# %%
within_traindev_df[(within_traindev_df['tag'] == 'gay marriage') & (within_traindev_df['tag'] == 'gay marriage')]
# Out:
#                                                argument1  \
# id
# 85249  gay marriage devalues marriage, frequency of o...
# 84168     marriage is defined as between a man and woman
# 85569  al rantell, a homosexual talk-show host in la....
# 89518        children have a claim to biological parents
# 6353   many laws already give civil unions equal bene...
# 92755  i agree with all my opponents rules and regula...
# 74517  gay parenting is just as good as straight pare...
# 93109  gay marriage is not the same as marriage equal...
# 9406   civil unions give gays equal benefits w/o chan...
# 85959  gay marriage devalues the institution of marriage
# 86952  gays can already obtain most benefits of marriage
# 3888   i thank pro for their opening argument.premise...
# 81367  gays raise children now, but at a disadvantage...
# 84333  gay marriage undercuts procreation at time of ...
# 74826         civil unions are "separate, but not equal"
# 85701    marriage is about love/commitment; gays qualify
# 6715   civil unions can be pushed to include equal be...
# 3323   i shall wait for my opponent to deliver an arg...
# 8521   civil union "compromise" is inappropriate half...
# 20389  the only argument against gay marriage is that...
# 22513  let me ask again; what is the purpose of the m...
# 449    i will quote my opponent an then respond to wh...
# 84715       civil unions offer same benefits as marriage
# 9068         marriage is more than a religious practice.
# 5982   civil unions would give gays all the benefits ...
# 74838         civil unions are "separate, but not equal"
# 86672   gay marriage ban is incomparable to biracial ban
# 82134  gay marriage is a fundamental, equal right ted...
# 74264       many dictionaries include gays in "marriage"
# 27760  my argument against gay marriage is compelling...
# ...                                                  ...
# 73172  gay marriage is separate issue from gay parenting
# 8455   civil unions are "separate, but not equal" dur...
# 73427  gay marriage exists successfully in many count...
# 73407       civil unions offer same benefits as marriage
# 92588  both of these contentions will be addressed. -...
# 8459   civil unions are "separate, but not equal" dur...
# 80784  gay marriage "slippery slope" argument is scar...
# 78209  gay marriage ban is analogous to interracial m...
# 73660  gays are taxpaying citizens, deserve marriage ...
# 87011  religious arguments are unacceptable on civil ...
# 78645  gay marriage is a civil, not religious, issue ...
# 79115  marriage is a commitment to love and care for ...
# 85424  gay parenting is just as good as straight pare...
# 28018  married couples do have legal benefits, but th...
# 83803  marriage gives gays a sense of future, purpose...
# 93187  hello monk: with my analogy of a math problem,...
# 92077  homosexual activist argue that same-sex "marri...
# 28783  gay marriage is as bad as this debate topic as...
# 74551  gay parenting is just as good as straight pare...
# 73011  being married is a source of stability and com...
# 75158  al rantell, a homosexual talk-show host in la....
# 93170  thank you for helping me make my point? i said...
# 86474  definition of marriage can and should evolve t...
# 10381  civil unions avoid drawn out culture war on ga...
# 76047  children do not need male/female parent role m...
# 7300   success rate of gay marriages is an inappropri...
# 19480  i never said exclude rights, rather that right...
# 72197  marriage allows gays to see each other in hosp...
# 74829         civil unions are "separate, but not equal"
# 3298   in responseyada is indeed the hebrew form and ...
#
#                                   argument1_id  \
# id
# 85249  d2f4b1cd-2019-04-17T11:47:27Z-00063-000
# 84168  d2f4b1cd-2019-04-17T11:47:27Z-00092-000
# 85569  d2f4b1cd-2019-04-17T11:47:27Z-00154-000
# 89518  d2f4b1cd-2019-04-17T11:47:27Z-00028-000
# 6353   40f91664-2019-04-17T11:47:29Z-00064-000
# 92755  ea2e9a61-2019-04-18T17:43:10Z-00008-000
# 74517  d2f4b1cd-2019-04-17T11:47:27Z-00033-000
# 93109   eb8b217-2019-04-18T17:33:54Z-00006-000
# 9406   40f91664-2019-04-17T11:47:29Z-00050-000
# 85959  d2f4b1cd-2019-04-17T11:47:27Z-00064-000
# 93170          True                     gay marriage should be allowed
# 86474         False          gay marriage, debate on same sex marriage
# 10381         False                      civil unions vs. gay marriage
# 76047          True          gay marriage, debate on same sex marriage
# 7300           True                      civil unions vs. gay marriage
# 19480         False                                       gay marriage
# 72197          True          gay marriage, debate on same sex marriage
# 74829          True          gay marriage, debate on same sex marriage
# 3298          False                                       gay marriage
#
#                 tag
# id
# 85249  gay marriage
# 84168  gay marriage
# 85569  gay marriage
# 89518  gay marriage
# 6353   gay marriage
# 92755  gay marriage
# 74517  gay marriage
# 93109  gay marriage
# 9406   gay marriage
# 85959  gay marriage
# 86952  gay marriage
# 3888   gay marriage
# 81367  gay marriage
# 84333  gay marriage
# 74826  gay marriage
# 85701  gay marriage
# 6715   gay marriage
# 3323   gay marriage
# 8521   gay marriage
# 20389  gay marriage
# 22513  gay marriage
# 449    gay marriage
# 84715  gay marriage
# 9068   gay marriage
# 5982   gay marriage
# 74838  gay marriage
# 86672  gay marriage
# 82134  gay marriage
# 74264  gay marriage
# 27760  gay marriage
# ...             ...
# 73172  gay marriage
# 8455   gay marriage
# 73427  gay marriage
# 73407  gay marriage
# 92588  gay marriage
# 8459   gay marriage
# 80784  gay marriage
# 78209  gay marriage
# 73660  gay marriage
# 87011  gay marriage
# 78645  gay marriage
# 79115  gay marriage
# 85424  gay marriage
# 28018  gay marriage
# 83803  gay marriage
# 93187  gay marriage
# 92077  gay marriage
# 28783  gay marriage
# 74551  gay marriage
# 73011  gay marriage
# 75158  gay marriage
# 93170  gay marriage
# 86474  gay marriage
# 10381  gay marriage
# 76047  gay marriage
# 7300   gay marriage
# 19480  gay marriage
# 72197  gay marriage
# 74829  gay marriage
# 3298   gay marriage
#
# [23063 rows x 8 columns]

# %% [markdown]
# ### Approach

# %%
# %autoreload
from cnn_siamese import *
from cnn_siamese_train import *
import torchtext.data as data

# %%
X_train, X_dev, y_train, y_dev = get_train_test_sets(cross_traindev_df)

# %%
x1_train, x2_train, y_train = df_to_lists(X_train, y_train)

# %%
x1_dev, x2_dev, y_dev = df_to_lists(X_dev, y_dev)

# %%
text_field = data.Field(lower=True)
label_field = data.Field(sequential=False)

# %%
train_data = list(zip(x1_train, x2_train))
dev_data   = list(zip(x1_dev, x2_dev))

train_data = list(zip(train_data, y_train))
dev_data   = list(zip(dev_data, y_dev))

# %%
train_ds = MR(text_field, label_field, train_data)
dev_ds = MR(text_field, label_field, dev_data)

# %%
text_field.build_vocab(train_ds, dev_ds)
label_field.build_vocab(train_ds, dev_ds)

# %%
train_iter, dev_iter = data.Iterator.splits((train_ds, dev_ds), batch_sizes=(16, len(dev_ds)))

# %%
vocab_len = len(text_field.vocab)

cnn = CNN_Siamese(vocab_len)
cnn = cnn.cuda()

# %%
train(train_iter, dev_iter, cnn)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-21-ec6604b3e828> in <module>()
# ----> 1 train(train_iter, dev_iter, cnn)
#
# /workspace/code/cnn_siamese_train.py in train(train_iter, dev_iter, model, epochs)
#      24             logit = model(feature1, feature2)
#      25
# ---> 26             loss = F.cross_entropy(logit, target)
#      27
#      28             print(loss)
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction)
#    1548     if size_average is not None or reduce is not None:
#    1549         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 1550     return nll_loss(log_softmax(input, 1), target, weight, None, ignore_index, None, reduction)
#    1551
#    1552
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py in nll_loss(input, target, weight, size_average, ignore_index, reduce, reduction)
#    1405                          .format(input.size(0), target.size(0)))
#    1406     if dim == 2:
# -> 1407         return torch._C._nn.nll_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index)
#    1408     elif dim == 4:
#    1409         return torch._C._nn.nll_loss2d(input, target, weight, _Reduction.get_enum(reduction), ignore_index)
#
# RuntimeError: cuda runtime error (59) : device-side assert triggered at /pytorch/aten/src/THCUNN/generic/ClassNLLCriterion.cu:111

# %% [markdown]
# ### Test Model:

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
torch.tensor([1.2, 3.0]).cuda()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-da02b38f086d> in <module>()
# ----> 1 torch.tensor([1.2, 3.0]).cuda()
#
# RuntimeError: cuda runtime error (59) : device-side assert triggered at /pytorch/aten/src/THC/generic/THCTensorCopy.cpp:20

# %%
# Load the saved model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = SiameseNetwork().to(device)
model.load_state_dict(torch.load("/model.pt"))

# %%
test_dataset = SiameseNetworkDataset(x1_dev, x2_dev, y_dev)
test_dataloader = DataLoader(test_dataset, shuffle=True, num_workers=8,batch_size=1)

# %%
# Print the sample outputs to view its dissimilarity
counter=0
list_0 = torch.FloatTensor([[0]])
list_1 = torch.FloatTensor([[1]])
counter = 0
for i, data in enumerate(test_dataloader,0): 
    x0, x1 , label = data
    concatenated = torch.cat((x0,x1),0)
    output1,output2 = model(x0.to(device),x1.to(device))
    eucledian_distance = F.pairwise_distance(output1, output2)
    if label==list_0:
        label="Same Side"
    else:
        label="Different Side"
    print('Dissimilarity: {:.2f} Label: {}'.format(eucledian_distance.item(),label))
    counter +=1
    if counter > 10:
        break
# Out:
# Dissimilarity: 0.04 Label: Same Side
# Dissimilarity: 0.71 Label: Same Side
# Dissimilarity: 0.19 Label: Different Side
# Dissimilarity: 0.00 Label: Different Side
# Dissimilarity: 0.41 Label: Same Side
# Dissimilarity: 0.45 Label: Different Side
# Dissimilarity: 0.00 Label: Same Side
# Dissimilarity: 0.84 Label: Different Side
# Dissimilarity: 0.79 Label: Same Side
# Dissimilarity: 0.57 Label: Different Side
# Dissimilarity: 0.45 Label: Different Side

# %%
accuracy=0
counter=0
correct=0
for i, data in enumerate(test_dataloader,0): 
    x0, x1 , label = data
    # onehsot applies in the output of 128 dense vectors which is then converted to 2 dense vectors
    output1,output2 = model(x0.to(device),x1.to(device))
    res=torch.abs(output1.cuda() - output2.cuda())
    label=label[0].tolist()
    label=int(label[0])
    result=torch.max(res,1)[1][0][0][0].data[0].tolist()
    if label == result:
        correct=correct+1
        counter=counter+1
    
accuracy=(correct/len(test_dataloader))*100
print("Accuracy:{}%".format(accuracy))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   # This is added back by InteractiveShellApp.init_path()
# Accuracy:13.475293475293476%
